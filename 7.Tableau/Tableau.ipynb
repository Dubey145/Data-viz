# %% [markdown]
# # why data viz is important

# %% [markdown]
# data might have the same statistical features<br>
# viz will tell us how that data is different

# %% [markdown]
# ![Screenshot%202022-05-09%20at%205.05.43%20AM.png](attachment:Screenshot%202022-05-09%20at%205.05.43%20AM.png)

# %% [markdown]
# plotting the data with MPL

# %% [markdown]
# ![Screenshot%202022-05-09%20at%205.07.07%20AM.png](attachment:Screenshot%202022-05-09%20at%205.07.07%20AM.png)
# there seems to be some relation with x and y, with x increasing y also increases

# %% [markdown]
# ![Screenshot%202022-05-09%20at%205.08.31%20AM.png](attachment:Screenshot%202022-05-09%20at%205.08.31%20AM.png)

# %% [markdown]
# ![Screenshot%202022-05-09%20at%205.09.21%20AM.png](attachment:Screenshot%202022-05-09%20at%205.09.21%20AM.png)

# %% [markdown]
# ![Screenshot%202022-05-09%20at%205.09.58%20AM.png](attachment:Screenshot%202022-05-09%20at%205.09.58%20AM.png)
